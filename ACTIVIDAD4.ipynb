# %% [markdown]
# # 4th prg

# %%
import threading, os

# %%
! ipconfig
# Out:
# Configuraci¢n IP de Windows
#
#
# Adaptador de Ethernet Ethernet:
#
#    Estado de los medios. . . . . . . . . . . : medios desconectados
#    Sufijo DNS espec¡fico para la conexi¢n. . :
#
# Adaptador de Ethernet Ethernet 3:
#
#    Estado de los medios. . . . . . . . . . . : medios desconectados
#    Sufijo DNS espec¡fico para la conexi¢n. . :
#
# Adaptador de LAN inal mbrica Conexi¢n de  rea local* 1:
#
#    Estado de los medios. . . . . . . . . . . : medios desconectados
#    Sufijo DNS espec¡fico para la conexi¢n. . :
#
# Adaptador de LAN inal mbrica Conexi¢n de  rea local* 10:
#
#    Estado de los medios. . . . . . . . . . . : medios desconectados
#    Sufijo DNS espec¡fico para la conexi¢n. . :
#
# Adaptador de Ethernet Ethernet 2:
#
#    Estado de los medios. . . . . . . . . . . : medios desconectados
#    Sufijo DNS espec¡fico para la conexi¢n. . :
#
# Adaptador de LAN inal mbrica Wi-Fi:
#
#    Sufijo DNS espec¡fico para la conexi¢n. . :
# ...

# %%
from IPython import display
display.Image("Captura123.JPG")

# %%
def pingAlv():
    ! ping(10.34.80.23)

# %%
for i in range(1):
    os.popen("threading.Thread(pingAlv()).start()")

# %%
! ping 10.34.80.23 -l 65500 -w 1 -n 1
# Out:
# Haciendo ping a 10.34.80.23 con 65500 bytes de datos:
# Tiempo de espera agotado para esta solicitud.
#
# Estad¡sticas de ping para 10.34.80.23:
#     Paquetes: enviados = 1, recibidos = 0, perdidos = 1
#     (100% perdidos),

# %%
for i in range(1):
    threading.Thread(pingAlv()).start()
# Out:
# La solicitud de ping no pudo encontrar el host (). Compruebe el nombre y
# vuelva a intentarlo.

# %%
res_ = os.popen("ping 10.34.80.23 -l 65500 -w 1 -n 1")
threading.Thread(target = res_).start()
# Out:
# Exception in thread Thread-13:
# Traceback (most recent call last):
#   File "C:\Users\crisd\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\crisd\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: '_wrap_close' object is not callable
