# %% [markdown]
# # FIRST PRG

# %% [markdown]
# ## Imprimir la sec. de fib de los numeros 30, 50, 80.

# %% [markdown]
# ### La formula usada es:

# %%
from IPython import display

# %%
display.Image("Fib.JPG")

# %%
def fib(n):
    if n<=1:
        return n
    else:
        return (fib(n-1)+fib(n-2))

# %%
fib(30)

# %%
fib(50)

# %%
def f(n):
    if n<=1:
        return n
    else:
        print(os.getpid())
        return (f(n-1)+f(n-2))
